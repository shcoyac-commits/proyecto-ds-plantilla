# %%
import pandas as pd

# %%
tickets ={
    "id_ticket": [1001,1002,1003,1004]
    "articulo": ["paracetamol","cafe americano", "ibuprofeno", "agua"],
    "categoria": ["medicamento","cafe","medicamento","bebida"]
    "cantidad": [2,1,1,3]
    "precio_unitario": [25.50,18.0,35.0,15.0]
        }
df=pd.DataFrame(tickets)
print(df)
# Out:
#   Cell In[2], line 2
#     "id_ticket": [1001,1002,1003,1004]
#                  ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
tickets ={
    "id_ticket": [1001,1002,1003,1004]
    "articulo": ["paracetamol","cafe americano", "ibuprofeno", "agua"],
    "categoria": ["medicamento","cafe","medicamento","bebida"]
    "cantidad": [2,1,1,3]
    "precio_unitario": [25.50,18.0,35.0,15.0]
        }
df=pd.DataFrame(tickets)
print(df)
# Out:
#   Cell In[2], line 2
#     "id_ticket": [1001,1002,1003,1004]
#                  ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
tickets ={
    "id_ticket": [1001,1002,1003,1004],
    "articulo": ["paracetamol","cafe americano", "ibuprofeno", "agua"],
    "categoria": ["medicamento","cafe","medicamento","bebida"],
    "cantidad": [2,1,1,3],
    "precio_unitario": [25.50,18.0,35.0,15.0]
        }
df=pd.DataFrame(tickets)
print(df)
# Out:
#    id_ticket        articulo    categoria  cantidad  precio_unitario
# 0       1001     paracetamol  medicamento         2             25.5
# 1       1002  cafe americano         cafe         1             18.0
# 2       1003      ibuprofeno  medicamento         1             35.0
# 3       1004            agua       bebida         3             15.0

# %%
df.head()
# Out:
#    id_ticket        articulo    categoria  cantidad  precio_unitario
# 0       1001     paracetamol  medicamento         2             25.5
# 1       1002  cafe americano         cafe         1             18.0
# 2       1003      ibuprofeno  medicamento         1             35.0
# 3       1004            agua       bebida         3             15.0

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id_ticket        4 non-null      int64
#  1   articulo         4 non-null      str
#  2   categoria        4 non-null      str
#  3   cantidad         4 non-null      int64
#  4   precio_unitario  4 non-null      float64
# dtypes: float64(1), int64(2), str(2)
# memory usage: 292.0 bytes

# %%
df.describe()
# Out:
#          id_ticket  cantidad  precio_unitario
# count     4.000000  4.000000         4.000000
# mean   1002.500000  1.750000        23.375000
# std       1.290994  0.957427         8.919781
# min    1001.000000  1.000000        15.000000
# 25%    1001.750000  1.000000        17.250000
# 50%    1002.500000  1.500000        21.750000
# 75%    1003.250000  2.250000        27.875000
# max    1004.000000  3.000000        35.000000

# %%
df[total]=df["cantidad"] * df ["precio_unitario"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df[total]=df["cantidad"] * df ["precio_unitario"]
#
# NameError: name 'total' is not defined

# %%
df["total"]=df["cantidad"]*df["precio_unitario"]
print [df]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 df["total"]=df["cantidad"]*df["precio_unitario"]
# ----> 2 print [df]
#
# TypeError: 'builtin_function_or_method' object is not subscriptable

# %%
df["total"]=df["cantidad"]*df["precio_unitario"]
print[df]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 df["total"]=df["cantidad"]*df["precio_unitario"]
# ----> 2 print[df]
#
# TypeError: 'builtin_function_or_method' object is not subscriptable

# %%
df["total"]=df["cantidad"]*["precio_unitario"]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 df["total"]=df["cantidad"]*["precio_unitario"]
#
# File ~\anaconda3\envs\analytics\Lib\site-packages\pandas\core\ops\common.py:85, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      82     other = sanitize_array(other, None)
#      83     other = ensure_wrapped_if_datetimelike(other)
# ---> 85 return method(self, other)
#
# File ~\anaconda3\envs\analytics\Lib\site-packages\pandas\core\arraylike.py:206, in OpsMixin.__mul__(self, other)
#     204 @unpack_zerodim_and_defer("__mul__")
#     205 def __mul__(self, other):
# --> 206     return self._arith_method(other, operator.mul)
#
# File ~\anaconda3\envs\analytics\Lib\site-packages\pandas\core\series.py:6751, in Series._arith_method(self, other, op)
#    6749 def _arith_method(self, other, op):
# ...

# %%
df["total"]=df["cantidad"]*df["precio_unitario"]

# %%
print(df)
# Out:
#    id_ticket        articulo    categoria  cantidad  precio_unitario  total
# 0       1001     paracetamol  medicamento         2             25.5   51.0
# 1       1002  cafe americano         cafe         1             18.0   18.0
# 2       1003      ibuprofeno  medicamento         1             35.0   35.0
# 3       1004            agua       bebida         3             15.0   45.0

# %%
medicamentos=df[df["categoria"]=="medicamento"]

# %%
print (medicamento)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 print (medicamento)
#
# NameError: name 'medicamento' is not defined

# %%
print (medicamentos)
# Out:
#    id_ticket     articulo    categoria  cantidad  precio_unitario  total
# 0       1001  paracetamol  medicamento         2             25.5   51.0
# 2       1003   ibuprofeno  medicamento         1             35.0   35.0

# %%
print(df[df["categoria"]== "medicamento"])
# Out:
#    id_ticket     articulo    categoria  cantidad  precio_unitario  total
# 0       1001  paracetamol  medicamento         2             25.5   51.0
# 2       1003   ibuprofeno  medicamento         1             35.0   35.0

# %%
df[df["total"]>30]
# Out:
#    id_ticket     articulo    categoria  cantidad  precio_unitario  total
# 0       1001  paracetamol  medicamento         2             25.5   51.0
# 2       1003   ibuprofeno  medicamento         1             35.0   35.0
# 3       1004         agua       bebida         3             15.0   45.0

# %%
df[df["categoria"}isin(["medicamento","bebida"])]
# Out:
#   Cell In[19], line 1
#     df[df["categoria"}isin(["medicamento","bebida"])]
#                      ^
# SyntaxError: closing parenthesis '}' does not match opening parenthesis '['

# %%
df[df["categoria"].isin(["medicamento","bebida"])]
# Out:
#    id_ticket     articulo    categoria  cantidad  precio_unitario  total
# 0       1001  paracetamol  medicamento         2             25.5   51.0
# 2       1003   ibuprofeno  medicamento         1             35.0   35.0
# 3       1004         agua       bebida         3             15.0   45.0

# %%
df[(df["categoria"}=="medicamento") & (df["cantidad"]>1]
# Out:
#   Cell In[21], line 1
#     df[(df["categoria"}=="medicamento") & (df["cantidad"]>1]
#                       ^
# SyntaxError: closing parenthesis '}' does not match opening parenthesis '['

# %%
df[(df["categoria"]=="medicamento") & (df["cantidad"] > 1)]
# Out:
#    id_ticket     articulo    categoria  cantidad  precio_unitario  total
# 0       1001  paracetamol  medicamento         2             25.5   51.0

# %%
df.groupby("categoria")["total"].sum()
# Out:
# categoria
# bebida         45.0
# cafe           18.0
# medicamento    86.0
# Name: total, dtype: float64

# %%
df.groupby("categoria")["total"].mean()
# Out:
# categoria
# bebida         45.0
# cafe           18.0
# medicamento    43.0
# Name: total, dtype: float64

# %%
df.groupby("categoria")["total"].count()
# Out:
# categoria
# bebida         1
# cafe           1
# medicamento    2
# Name: total, dtype: int64

# %%
df.groupby("categoria")["total"].max()
# Out:
# categoria
# bebida         45.0
# cafe           18.0
# medicamento    51.0
# Name: total, dtype: float64

# %%
df.groupby("categoria")["total"].agg(["sum", "mean", "count", "max"])
# Out:
#               sum  mean  count   max
# categoria
# bebida       45.0  45.0      1  45.0
# cafe         18.0  18.0      1  18.0
# medicamento  86.0  43.0      2  51.0

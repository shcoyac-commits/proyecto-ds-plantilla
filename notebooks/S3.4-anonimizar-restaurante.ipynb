# %%
import pandas as pd

# Cargar cheqdet CON EXTENSIÓN .csv
df_restaurante = pd.read_csv(r'C:\Users\Said\Documents\Datasets\SoftRes\cheqdet.csv')

print("SHAPE:")
print(df_restaurante.shape)

print("\nCOLUMNAS Y TIPOS:")
print(df_restaurante.dtypes)

print("\nPRIMERAS 3 FILAS:")
print(df_restaurante.head(3))

print("\nVALORES ÚNICOS (cardinalidad):")
for col in df_restaurante.columns:
    print(f"{col}: {df_restaurante[col].nunique()} únicos")
# Out:
# SHAPE:
# (398208, 17)
#
# COLUMNAS Y TIPOS:
# foliodet                int64
# movimiento              int64
# comanda               float64
# cantidad              float64
# idproducto              int64
# descuento             float64
# precio                float64
# impuesto1               int64
# impuesto2               int64
# impuesto3               int64
# preciosinimpuestos    float64
# hora                      str
# modificador             int64
# mitad                   int64
# idestacion                str
# idmeseroproducto      float64
# preciocatalogo        float64
# dtype: object
#
# PRIMERAS 3 FILAS:
#    foliodet  movimiento  comanda  cantidad  idproducto  descuento  precio  \
# 0         1           1      NaN       1.0         517        0.0    59.0
# 1         9           6      NaN       1.0        7101        0.0     0.0
# 2        13          33      NaN       1.0         518        0.0    59.0
#
# ...
